# %%
import os
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import glob
import cv2
import re

def extract_number(filename):
    """Extract the numeric part from a filename."""
    numbers = re.findall(r'\d+', filename)
    if numbers:
        return numbers[-1]  # Return the last number found
    return None

def load_png_mask(png_path):
    """Load a binary mask from a PNG file."""
    img = np.array(Image.open(png_path))
    # Convert to binary (0 or 1)
    return img > 0

def load_npy_mask(npy_path):
    """Load a binary mask from a NPY file."""
    return np.load(npy_path).astype(bool)

def resize_mask(mask, target_shape):
    """Resize a binary mask to target shape."""
    mask_uint8 = mask.astype(np.uint8) * 255
    resized = cv2.resize(mask_uint8, (target_shape[1], target_shape[0]),
                         interpolation=cv2.INTER_NEAREST)
    return resized > 0

def match_files_by_number(png_dir, npy_dir):
    """Match PNG and NPY files based on the numeric part in their filenames."""
    # Get all PNG files with their numbers
    png_files = glob.glob(os.path.join(png_dir, '*_bmask.png'))
    png_dict = {}
    for png_path in png_files:
        num = extract_number(os.path.basename(png_path))
        if num:
            png_dict[num] = png_path

    # Get all NPY files with their numbers
    npy_files = glob.glob(os.path.join(npy_dir, '*.npy'))
    matched_pairs = []

    for npy_path in npy_files:
        num = extract_number(os.path.basename(npy_path))
        if num and num in png_dict:
            matched_pairs.append((png_dict[num], npy_path))

    return matched_pairs

def calculate_iou(mask1, mask2):
    """Calculate IoU between two binary masks."""
    intersection = np.logical_and(mask1, mask2).sum()
    union = np.logical_or(mask1, mask2).sum()

    if union == 0:
        return 0.0  # Handle edge case where both masks are empty

    return intersection / union

def visualize_comparison(png_path, npy_path, output_dir, target_shape=None):
    """Visualize prediction mask and ground truth overlaid."""
    print(f"Processing: {os.path.basename(png_path)} and {os.path.basename(npy_path)}")

    # Load masks
    pred_mask = load_png_mask(png_path)
    gt_mask = load_npy_mask(npy_path)

    # Print original shapes for debugging
    print(f"Original shapes - Prediction: {pred_mask.shape}, Ground Truth: {gt_mask.shape}")

    # If target shape not specified, use the ground truth shape
    if target_shape is None:
        target_shape = gt_mask.shape

    # Resize masks if needed
    if pred_mask.shape != target_shape:
        pred_mask = resize_mask(pred_mask, target_shape)
    if gt_mask.shape != target_shape:
        gt_mask = resize_mask(gt_mask, target_shape)

    # Calculate IoU
    iou = calculate_iou(pred_mask, gt_mask)

    # Create RGB visualization
    viz = np.zeros((*target_shape, 3), dtype=np.uint8)

    # Red channel (prediction only - False Positives)
    viz[..., 0] = np.logical_and(pred_mask, np.logical_not(gt_mask)) * 255

    # Green channel (ground truth only - False Negatives)
    viz[..., 1] = np.logical_and(np.logical_not(pred_mask), gt_mask) * 255

    # Both Red and Green channels (overlap - True Positives)
    overlap = np.logical_and(pred_mask, gt_mask)
    viz[overlap, 0] = 255
    viz[overlap, 1] = 255

    # Calculate metrics
    true_pos = np.sum(overlap)
    false_pos = np.sum(np.logical_and(pred_mask, np.logical_not(gt_mask)))
    false_neg = np.sum(np.logical_and(np.logical_not(pred_mask), gt_mask))

    # Create figure
    plt.figure(figsize=(12, 10))

    # Plot original masks side by side
    plt.subplot(2, 3, 1)
    plt.imshow(pred_mask, cmap='gray')
    plt.title(f'Prediction')
    plt.axis('off')

    plt.subplot(2, 3, 2)
    plt.imshow(gt_mask, cmap='gray')
    plt.title(f'Ground Truth')
    plt.axis('off')

    # plot the original image
    plt.subplot(2, 3, 3)
    plt.imshow(Image.open(npy_path.replace('.npy', '.png')))
    #/content/dataset/test/ISIC_0024309.npy
    plt.title(f'Original Image')
    plt.axis('off')

    # Plot comparison visualization
    plt.subplot(2, 1, 2)
    plt.imshow(viz)
    plt.title(f'Comparison (IoU: {iou:.4f})\n'
              f'Yellow: True Positive ({true_pos} px)\n'
              f'Red: False Positive ({false_pos} px)\n'
              f'Green: False Negative ({false_neg} px)')
    plt.axis('off')

    # Extract number for the output filename
    number = extract_number(os.path.basename(png_path)) or extract_number(os.path.basename(npy_path))
    output_path = os.path.join(output_dir, f"comparison_{number}.png")

    # Save figure
    plt.tight_layout()
    plt.savefig(output_path, dpi=100)
    plt.close()

    print(f"Saved comparison to {output_path}")

    return {
        'png_file': os.path.basename(png_path),
        'npy_file': os.path.basename(npy_path),
        'number': number,
        'iou': iou,
        'true_positive': true_pos,
        'false_positive': false_pos,
        'false_negative': false_neg
    }

def batch_visualize(png_dir, npy_dir, output_dir, target_shape=None):
    """Process all matching files in the directories."""
    # Create output directory if it doesn't exist
    os.makedirs(output_dir, exist_ok=True)

    # Match files by their numeric part
    matched_pairs = match_files_by_number(png_dir, npy_dir)
    print(f"Found {len(matched_pairs)} matching file pairs")

    results = []
    for png_path, npy_path in matched_pairs:
        result = visualize_comparison(png_path, npy_path, output_dir, target_shape)
        results.append(result)

    # Calculate average metrics and create a summary report
    if results:
        avg_iou = sum(r['iou'] for r in results) / len(results)
        print(f"\nProcessed {len(results)} images")
        print(f"Average IoU: {avg_iou:.4f}")

        # Save summary report
        report_path = os.path.join(output_dir, "summary_report.txt")
        with open(report_path, 'w') as f:
            f.write(f"Summary Report\n")
            f.write(f"=============\n\n")
            f.write(f"Total images processed: {len(results)}\n")
            f.write(f"Average IoU: {avg_iou:.4f}\n\n")
            f.write(f"Individual Results:\n")
            f.write(f"{'Number':<10} {'IoU':<10} {'PNG File':<30} {'NPY File':<30}\n")
            f.write(f"{'-'*80}\n")

            # Sort by IoU (descending)
            sorted_results = sorted(results, key=lambda x: x['iou'], reverse=True)
            for r in sorted_results:
                f.write(f"{r['number']:<10} {r['iou']:<10.4f} {r['png_file']:<30} {r['npy_file']:<30}\n")

        print(f"Summary report saved to {report_path}")

    return results

# Example usage
if __name__ == "__main__":
    # Set your actual directories
    png_masks_dir = "results"  # Prediction masks (352x352)
    npy_masks_dir = "datasets/dataset/test"  # Ground truth masks (512x512)
    output_dir = "comparison_results"

    # Choose target shape - using ground truth shape (512x512)
    target_shape = (512, 512)

    results = batch_visualize(png_masks_dir, npy_masks_dir, output_dir, target_shape)
# Out:
# Found 681 matching file pairs
# Processing: ISIC_0024319_bmask.png and ISIC_0024319.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024319.png
# Processing: ISIC_0024320_bmask.png and ISIC_0024320.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024320.png
# Processing: ISIC_0024321_bmask.png and ISIC_0024321.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024321.png
# Processing: ISIC_0024322_bmask.png and ISIC_0024322.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024322.png
# Processing: ISIC_0024323_bmask.png and ISIC_0024323.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024323.png
# Processing: ISIC_0024324_bmask.png and ISIC_0024324.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024324.png
# Processing: ISIC_0024325_bmask.png and ISIC_0024325.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024325.png
# Processing: ISIC_0024326_bmask.png and ISIC_0024326.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024326.png
# Processing: ISIC_0024327_bmask.png and ISIC_0024327.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024327.png
# Processing: ISIC_0024328_bmask.png and ISIC_0024328.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024328.png
# Processing: ISIC_0024329_bmask.png and ISIC_0024329.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024329.png
# Processing: ISIC_0024330_bmask.png and ISIC_0024330.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024330.png
# Processing: ISIC_0024331_bmask.png and ISIC_0024331.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024331.png
# Processing: ISIC_0024332_bmask.png and ISIC_0024332.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024332.png
# Processing: ISIC_0024333_bmask.png and ISIC_0024333.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024333.png
# Processing: ISIC_0024334_bmask.png and ISIC_0024334.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024334.png
# Processing: ISIC_0024335_bmask.png and ISIC_0024335.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024335.png
# Processing: ISIC_0024336_bmask.png and ISIC_0024336.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024336.png
# Processing: ISIC_0024337_bmask.png and ISIC_0024337.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024337.png
# Processing: ISIC_0024338_bmask.png and ISIC_0024338.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024338.png
# Processing: ISIC_0024339_bmask.png and ISIC_0024339.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024339.png
# Processing: ISIC_0024340_bmask.png and ISIC_0024340.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024340.png
# Processing: ISIC_0024341_bmask.png and ISIC_0024341.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024341.png
# Processing: ISIC_0024342_bmask.png and ISIC_0024342.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024342.png
# Processing: ISIC_0024343_bmask.png and ISIC_0024343.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024343.png
# Processing: ISIC_0024344_bmask.png and ISIC_0024344.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024344.png
# Processing: ISIC_0024345_bmask.png and ISIC_0024345.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024345.png
# Processing: ISIC_0024346_bmask.png and ISIC_0024346.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024346.png
# Processing: ISIC_0024347_bmask.png and ISIC_0024347.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024347.png
# Processing: ISIC_0024348_bmask.png and ISIC_0024348.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024348.png
# Processing: ISIC_0024349_bmask.png and ISIC_0024349.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024349.png
# Processing: ISIC_0024350_bmask.png and ISIC_0024350.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024350.png
# Processing: ISIC_0024351_bmask.png and ISIC_0024351.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024351.png
# Processing: ISIC_0024352_bmask.png and ISIC_0024352.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024352.png
# Processing: ISIC_0024353_bmask.png and ISIC_0024353.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024353.png
# Processing: ISIC_0024354_bmask.png and ISIC_0024354.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024354.png
# Processing: ISIC_0024355_bmask.png and ISIC_0024355.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024355.png
# Processing: ISIC_0024356_bmask.png and ISIC_0024356.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024356.png
# Processing: ISIC_0024357_bmask.png and ISIC_0024357.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024357.png
# Processing: ISIC_0024358_bmask.png and ISIC_0024358.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024358.png
# Processing: ISIC_0024359_bmask.png and ISIC_0024359.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024359.png
# Processing: ISIC_0024360_bmask.png and ISIC_0024360.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024360.png
# Processing: ISIC_0024361_bmask.png and ISIC_0024361.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024361.png
# Processing: ISIC_0024362_bmask.png and ISIC_0024362.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024362.png
# Processing: ISIC_0024363_bmask.png and ISIC_0024363.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024363.png
# Processing: ISIC_0024364_bmask.png and ISIC_0024364.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024364.png
# Processing: ISIC_0024365_bmask.png and ISIC_0024365.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024365.png
# Processing: ISIC_0024366_bmask.png and ISIC_0024366.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024366.png
# Processing: ISIC_0024367_bmask.png and ISIC_0024367.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024367.png
# Processing: ISIC_0024368_bmask.png and ISIC_0024368.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024368.png
# Processing: ISIC_0024369_bmask.png and ISIC_0024369.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024369.png
# Processing: ISIC_0024370_bmask.png and ISIC_0024370.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024370.png
# Processing: ISIC_0024371_bmask.png and ISIC_0024371.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024371.png
# Processing: ISIC_0024372_bmask.png and ISIC_0024372.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024372.png
# Processing: ISIC_0024373_bmask.png and ISIC_0024373.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024373.png
# Processing: ISIC_0024374_bmask.png and ISIC_0024374.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024374.png
# Processing: ISIC_0024375_bmask.png and ISIC_0024375.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024375.png
# Processing: ISIC_0024376_bmask.png and ISIC_0024376.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024376.png
# Processing: ISIC_0024377_bmask.png and ISIC_0024377.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024377.png
# Processing: ISIC_0024378_bmask.png and ISIC_0024378.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024378.png
# Processing: ISIC_0024379_bmask.png and ISIC_0024379.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024379.png
# Processing: ISIC_0024380_bmask.png and ISIC_0024380.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024380.png
# Processing: ISIC_0024381_bmask.png and ISIC_0024381.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024381.png
# Processing: ISIC_0024382_bmask.png and ISIC_0024382.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024382.png
# Processing: ISIC_0024383_bmask.png and ISIC_0024383.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024383.png
# Processing: ISIC_0024384_bmask.png and ISIC_0024384.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024384.png
# Processing: ISIC_0024385_bmask.png and ISIC_0024385.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024385.png
# Processing: ISIC_0024386_bmask.png and ISIC_0024386.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024386.png
# Processing: ISIC_0024387_bmask.png and ISIC_0024387.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024387.png
# Processing: ISIC_0024388_bmask.png and ISIC_0024388.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024388.png
# Processing: ISIC_0024389_bmask.png and ISIC_0024389.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024389.png
# Processing: ISIC_0024390_bmask.png and ISIC_0024390.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024390.png
# Processing: ISIC_0024391_bmask.png and ISIC_0024391.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024391.png
# Processing: ISIC_0024392_bmask.png and ISIC_0024392.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024392.png
# Processing: ISIC_0024393_bmask.png and ISIC_0024393.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024393.png
# Processing: ISIC_0024394_bmask.png and ISIC_0024394.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024394.png
# Processing: ISIC_0024395_bmask.png and ISIC_0024395.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024395.png
# Processing: ISIC_0024396_bmask.png and ISIC_0024396.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024396.png
# Processing: ISIC_0024397_bmask.png and ISIC_0024397.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024397.png
# Processing: ISIC_0024398_bmask.png and ISIC_0024398.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024398.png
# Processing: ISIC_0024399_bmask.png and ISIC_0024399.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024399.png
# Processing: ISIC_0024400_bmask.png and ISIC_0024400.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024400.png
# Processing: ISIC_0024401_bmask.png and ISIC_0024401.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024401.png
# Processing: ISIC_0024402_bmask.png and ISIC_0024402.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024402.png
# Processing: ISIC_0024403_bmask.png and ISIC_0024403.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024403.png
# Processing: ISIC_0024404_bmask.png and ISIC_0024404.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024404.png
# Processing: ISIC_0024405_bmask.png and ISIC_0024405.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024405.png
# Processing: ISIC_0024406_bmask.png and ISIC_0024406.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024406.png
# Processing: ISIC_0024407_bmask.png and ISIC_0024407.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024407.png
# Processing: ISIC_0024408_bmask.png and ISIC_0024408.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024408.png
# Processing: ISIC_0024409_bmask.png and ISIC_0024409.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024409.png
# Processing: ISIC_0024410_bmask.png and ISIC_0024410.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024410.png
# Processing: ISIC_0024411_bmask.png and ISIC_0024411.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024411.png
# Processing: ISIC_0024412_bmask.png and ISIC_0024412.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024412.png
# Processing: ISIC_0024413_bmask.png and ISIC_0024413.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024413.png
# Processing: ISIC_0024414_bmask.png and ISIC_0024414.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024414.png
# Processing: ISIC_0024415_bmask.png and ISIC_0024415.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024415.png
# Processing: ISIC_0024416_bmask.png and ISIC_0024416.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024416.png
# Processing: ISIC_0024417_bmask.png and ISIC_0024417.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024417.png
# Processing: ISIC_0024418_bmask.png and ISIC_0024418.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024418.png
# Processing: ISIC_0024419_bmask.png and ISIC_0024419.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024419.png
# Processing: ISIC_0024420_bmask.png and ISIC_0024420.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024420.png
# Processing: ISIC_0024421_bmask.png and ISIC_0024421.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024421.png
# Processing: ISIC_0024422_bmask.png and ISIC_0024422.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024422.png
# Processing: ISIC_0024423_bmask.png and ISIC_0024423.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024423.png
# Processing: ISIC_0024424_bmask.png and ISIC_0024424.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024424.png
# Processing: ISIC_0024425_bmask.png and ISIC_0024425.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024425.png
# Processing: ISIC_0024426_bmask.png and ISIC_0024426.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024426.png
# Processing: ISIC_0024427_bmask.png and ISIC_0024427.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024427.png
# Processing: ISIC_0024428_bmask.png and ISIC_0024428.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024428.png
# Processing: ISIC_0024429_bmask.png and ISIC_0024429.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024429.png
# Processing: ISIC_0024430_bmask.png and ISIC_0024430.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024430.png
# Processing: ISIC_0024431_bmask.png and ISIC_0024431.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024431.png
# Processing: ISIC_0024432_bmask.png and ISIC_0024432.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024432.png
# Processing: ISIC_0024433_bmask.png and ISIC_0024433.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024433.png
# Processing: ISIC_0024434_bmask.png and ISIC_0024434.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024434.png
# Processing: ISIC_0024435_bmask.png and ISIC_0024435.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024435.png
# Processing: ISIC_0024436_bmask.png and ISIC_0024436.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024436.png
# Processing: ISIC_0024437_bmask.png and ISIC_0024437.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024437.png
# Processing: ISIC_0024438_bmask.png and ISIC_0024438.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024438.png
# Processing: ISIC_0024439_bmask.png and ISIC_0024439.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024439.png
# Processing: ISIC_0024440_bmask.png and ISIC_0024440.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024440.png
# Processing: ISIC_0024441_bmask.png and ISIC_0024441.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024441.png
# Processing: ISIC_0024442_bmask.png and ISIC_0024442.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024442.png
# Processing: ISIC_0024443_bmask.png and ISIC_0024443.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024443.png
# Processing: ISIC_0024444_bmask.png and ISIC_0024444.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024444.png
# Processing: ISIC_0024445_bmask.png and ISIC_0024445.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024445.png
# Processing: ISIC_0024446_bmask.png and ISIC_0024446.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024446.png
# Processing: ISIC_0024447_bmask.png and ISIC_0024447.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024447.png
# Processing: ISIC_0024448_bmask.png and ISIC_0024448.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024448.png
# Processing: ISIC_0024449_bmask.png and ISIC_0024449.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024449.png
# Processing: ISIC_0024450_bmask.png and ISIC_0024450.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024450.png
# Processing: ISIC_0024451_bmask.png and ISIC_0024451.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024451.png
# Processing: ISIC_0024452_bmask.png and ISIC_0024452.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024452.png
# Processing: ISIC_0024453_bmask.png and ISIC_0024453.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024453.png
# Processing: ISIC_0024454_bmask.png and ISIC_0024454.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024454.png
# Processing: ISIC_0024455_bmask.png and ISIC_0024455.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024455.png
# Processing: ISIC_0024456_bmask.png and ISIC_0024456.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024456.png
# Processing: ISIC_0024457_bmask.png and ISIC_0024457.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024457.png
# Processing: ISIC_0024458_bmask.png and ISIC_0024458.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024458.png
# Processing: ISIC_0024459_bmask.png and ISIC_0024459.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024459.png
# Processing: ISIC_0024460_bmask.png and ISIC_0024460.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024460.png
# Processing: ISIC_0024461_bmask.png and ISIC_0024461.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024461.png
# Processing: ISIC_0024462_bmask.png and ISIC_0024462.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024462.png
# Processing: ISIC_0024463_bmask.png and ISIC_0024463.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024463.png
# Processing: ISIC_0024464_bmask.png and ISIC_0024464.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024464.png
# Processing: ISIC_0024465_bmask.png and ISIC_0024465.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024465.png
# Processing: ISIC_0024466_bmask.png and ISIC_0024466.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024466.png
# Processing: ISIC_0024467_bmask.png and ISIC_0024467.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024467.png
# Processing: ISIC_0024468_bmask.png and ISIC_0024468.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024468.png
# Processing: ISIC_0024469_bmask.png and ISIC_0024469.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024469.png
# Processing: ISIC_0024470_bmask.png and ISIC_0024470.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024470.png
# Processing: ISIC_0024471_bmask.png and ISIC_0024471.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024471.png
# Processing: ISIC_0024472_bmask.png and ISIC_0024472.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024472.png
# Processing: ISIC_0024473_bmask.png and ISIC_0024473.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024473.png
# Processing: ISIC_0024474_bmask.png and ISIC_0024474.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024474.png
# Processing: ISIC_0024475_bmask.png and ISIC_0024475.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024475.png
# Processing: ISIC_0024476_bmask.png and ISIC_0024476.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024476.png
# Processing: ISIC_0024477_bmask.png and ISIC_0024477.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024477.png
# Processing: ISIC_0024478_bmask.png and ISIC_0024478.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024478.png
# Processing: ISIC_0024479_bmask.png and ISIC_0024479.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024479.png
# Processing: ISIC_0024480_bmask.png and ISIC_0024480.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024480.png
# Processing: ISIC_0024481_bmask.png and ISIC_0024481.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024481.png
# Processing: ISIC_0024482_bmask.png and ISIC_0024482.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024482.png
# Processing: ISIC_0024483_bmask.png and ISIC_0024483.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024483.png
# Processing: ISIC_0024484_bmask.png and ISIC_0024484.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024484.png
# Processing: ISIC_0024485_bmask.png and ISIC_0024485.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024485.png
# Processing: ISIC_0024486_bmask.png and ISIC_0024486.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024486.png
# Processing: ISIC_0024487_bmask.png and ISIC_0024487.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024487.png
# Processing: ISIC_0024488_bmask.png and ISIC_0024488.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024488.png
# Processing: ISIC_0024489_bmask.png and ISIC_0024489.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024489.png
# Processing: ISIC_0024490_bmask.png and ISIC_0024490.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024490.png
# Processing: ISIC_0024491_bmask.png and ISIC_0024491.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024491.png
# Processing: ISIC_0024492_bmask.png and ISIC_0024492.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024492.png
# Processing: ISIC_0024493_bmask.png and ISIC_0024493.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024493.png
# Processing: ISIC_0024494_bmask.png and ISIC_0024494.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024494.png
# Processing: ISIC_0024495_bmask.png and ISIC_0024495.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024495.png
# Processing: ISIC_0024496_bmask.png and ISIC_0024496.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024496.png
# Processing: ISIC_0024497_bmask.png and ISIC_0024497.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024497.png
# Processing: ISIC_0024498_bmask.png and ISIC_0024498.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024498.png
# Processing: ISIC_0024499_bmask.png and ISIC_0024499.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024499.png
# Processing: ISIC_0024500_bmask.png and ISIC_0024500.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024500.png
# Processing: ISIC_0024501_bmask.png and ISIC_0024501.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024501.png
# Processing: ISIC_0024502_bmask.png and ISIC_0024502.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024502.png
# Processing: ISIC_0024503_bmask.png and ISIC_0024503.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024503.png
# Processing: ISIC_0024504_bmask.png and ISIC_0024504.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024504.png
# Processing: ISIC_0024505_bmask.png and ISIC_0024505.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024505.png
# Processing: ISIC_0024506_bmask.png and ISIC_0024506.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024506.png
# Processing: ISIC_0024507_bmask.png and ISIC_0024507.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024507.png
# Processing: ISIC_0024508_bmask.png and ISIC_0024508.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024508.png
# Processing: ISIC_0024509_bmask.png and ISIC_0024509.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024509.png
# Processing: ISIC_0024510_bmask.png and ISIC_0024510.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024510.png
# Processing: ISIC_0024511_bmask.png and ISIC_0024511.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024511.png
# Processing: ISIC_0024512_bmask.png and ISIC_0024512.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024512.png
# Processing: ISIC_0024513_bmask.png and ISIC_0024513.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024513.png
# Processing: ISIC_0024514_bmask.png and ISIC_0024514.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024514.png
# Processing: ISIC_0024515_bmask.png and ISIC_0024515.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024515.png
# Processing: ISIC_0024516_bmask.png and ISIC_0024516.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024516.png
# Processing: ISIC_0024517_bmask.png and ISIC_0024517.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024517.png
# Processing: ISIC_0024518_bmask.png and ISIC_0024518.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024518.png
# Processing: ISIC_0024519_bmask.png and ISIC_0024519.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024519.png
# Processing: ISIC_0024520_bmask.png and ISIC_0024520.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024520.png
# Processing: ISIC_0024521_bmask.png and ISIC_0024521.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024521.png
# Processing: ISIC_0024522_bmask.png and ISIC_0024522.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024522.png
# Processing: ISIC_0024523_bmask.png and ISIC_0024523.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024523.png
# Processing: ISIC_0024524_bmask.png and ISIC_0024524.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024524.png
# Processing: ISIC_0024525_bmask.png and ISIC_0024525.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024525.png
# Processing: ISIC_0024526_bmask.png and ISIC_0024526.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024526.png
# Processing: ISIC_0024527_bmask.png and ISIC_0024527.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024527.png
# Processing: ISIC_0024528_bmask.png and ISIC_0024528.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024528.png
# Processing: ISIC_0024529_bmask.png and ISIC_0024529.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024529.png
# Processing: ISIC_0024530_bmask.png and ISIC_0024530.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024530.png
# Processing: ISIC_0024531_bmask.png and ISIC_0024531.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024531.png
# Processing: ISIC_0024532_bmask.png and ISIC_0024532.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024532.png
# Processing: ISIC_0024533_bmask.png and ISIC_0024533.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024533.png
# Processing: ISIC_0024534_bmask.png and ISIC_0024534.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024534.png
# Processing: ISIC_0024535_bmask.png and ISIC_0024535.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024535.png
# Processing: ISIC_0024536_bmask.png and ISIC_0024536.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024536.png
# Processing: ISIC_0024537_bmask.png and ISIC_0024537.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024537.png
# Processing: ISIC_0024538_bmask.png and ISIC_0024538.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024538.png
# Processing: ISIC_0024539_bmask.png and ISIC_0024539.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024539.png
# Processing: ISIC_0024540_bmask.png and ISIC_0024540.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024540.png
# Processing: ISIC_0024541_bmask.png and ISIC_0024541.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024541.png
# Processing: ISIC_0024542_bmask.png and ISIC_0024542.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024542.png
# Processing: ISIC_0024543_bmask.png and ISIC_0024543.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024543.png
# Processing: ISIC_0024544_bmask.png and ISIC_0024544.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024544.png
# Processing: ISIC_0024545_bmask.png and ISIC_0024545.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024545.png
# Processing: ISIC_0024546_bmask.png and ISIC_0024546.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024546.png
# Processing: ISIC_0024547_bmask.png and ISIC_0024547.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024547.png
# Processing: ISIC_0024548_bmask.png and ISIC_0024548.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024548.png
# Processing: ISIC_0024549_bmask.png and ISIC_0024549.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024549.png
# Processing: ISIC_0024550_bmask.png and ISIC_0024550.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024550.png
# Processing: ISIC_0024551_bmask.png and ISIC_0024551.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024551.png
# Processing: ISIC_0024552_bmask.png and ISIC_0024552.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024552.png
# Processing: ISIC_0024553_bmask.png and ISIC_0024553.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024553.png
# Processing: ISIC_0024554_bmask.png and ISIC_0024554.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024554.png
# Processing: ISIC_0024555_bmask.png and ISIC_0024555.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024555.png
# Processing: ISIC_0024556_bmask.png and ISIC_0024556.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024556.png
# Processing: ISIC_0024557_bmask.png and ISIC_0024557.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024557.png
# Processing: ISIC_0024558_bmask.png and ISIC_0024558.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024558.png
# Processing: ISIC_0024559_bmask.png and ISIC_0024559.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024559.png
# Processing: ISIC_0024560_bmask.png and ISIC_0024560.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024560.png
# Processing: ISIC_0024561_bmask.png and ISIC_0024561.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024561.png
# Processing: ISIC_0024562_bmask.png and ISIC_0024562.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024562.png
# Processing: ISIC_0024563_bmask.png and ISIC_0024563.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024563.png
# Processing: ISIC_0024564_bmask.png and ISIC_0024564.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024564.png
# Processing: ISIC_0024565_bmask.png and ISIC_0024565.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024565.png
# Processing: ISIC_0024566_bmask.png and ISIC_0024566.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024566.png
# Processing: ISIC_0024567_bmask.png and ISIC_0024567.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024567.png
# Processing: ISIC_0024568_bmask.png and ISIC_0024568.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024568.png
# Processing: ISIC_0024569_bmask.png and ISIC_0024569.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024569.png
# Processing: ISIC_0024570_bmask.png and ISIC_0024570.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024570.png
# Processing: ISIC_0024571_bmask.png and ISIC_0024571.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024571.png
# Processing: ISIC_0024572_bmask.png and ISIC_0024572.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024572.png
# Processing: ISIC_0024573_bmask.png and ISIC_0024573.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024573.png
# Processing: ISIC_0024574_bmask.png and ISIC_0024574.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024574.png
# Processing: ISIC_0024575_bmask.png and ISIC_0024575.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024575.png
# Processing: ISIC_0024576_bmask.png and ISIC_0024576.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024576.png
# Processing: ISIC_0024577_bmask.png and ISIC_0024577.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024577.png
# ...
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024914.png
# Processing: ISIC_0024915_bmask.png and ISIC_0024915.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024915.png
# Processing: ISIC_0024916_bmask.png and ISIC_0024916.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024916.png
# Processing: ISIC_0024917_bmask.png and ISIC_0024917.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024917.png
# Processing: ISIC_0024918_bmask.png and ISIC_0024918.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024918.png
# Processing: ISIC_0024919_bmask.png and ISIC_0024919.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024919.png
# Processing: ISIC_0024920_bmask.png and ISIC_0024920.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024920.png
# Processing: ISIC_0024921_bmask.png and ISIC_0024921.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024921.png
# Processing: ISIC_0024922_bmask.png and ISIC_0024922.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024922.png
# Processing: ISIC_0024923_bmask.png and ISIC_0024923.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024923.png
# Processing: ISIC_0024924_bmask.png and ISIC_0024924.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024924.png
# Processing: ISIC_0024925_bmask.png and ISIC_0024925.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024925.png
# Processing: ISIC_0024926_bmask.png and ISIC_0024926.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024926.png
# Processing: ISIC_0024927_bmask.png and ISIC_0024927.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024927.png
# Processing: ISIC_0024928_bmask.png and ISIC_0024928.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024928.png
# Processing: ISIC_0024929_bmask.png and ISIC_0024929.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024929.png
# Processing: ISIC_0024930_bmask.png and ISIC_0024930.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024930.png
# Processing: ISIC_0024931_bmask.png and ISIC_0024931.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024931.png
# Processing: ISIC_0024932_bmask.png and ISIC_0024932.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024932.png
# Processing: ISIC_0024933_bmask.png and ISIC_0024933.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024933.png
# Processing: ISIC_0024934_bmask.png and ISIC_0024934.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024934.png
# Processing: ISIC_0024935_bmask.png and ISIC_0024935.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024935.png
# Processing: ISIC_0024936_bmask.png and ISIC_0024936.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024936.png
# Processing: ISIC_0024937_bmask.png and ISIC_0024937.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024937.png
# Processing: ISIC_0024938_bmask.png and ISIC_0024938.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024938.png
# Processing: ISIC_0024939_bmask.png and ISIC_0024939.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024939.png
# Processing: ISIC_0024940_bmask.png and ISIC_0024940.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024940.png
# Processing: ISIC_0024941_bmask.png and ISIC_0024941.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024941.png
# Processing: ISIC_0024942_bmask.png and ISIC_0024942.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024942.png
# Processing: ISIC_0024943_bmask.png and ISIC_0024943.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024943.png
# Processing: ISIC_0024944_bmask.png and ISIC_0024944.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024944.png
# Processing: ISIC_0024945_bmask.png and ISIC_0024945.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024945.png
# Processing: ISIC_0024946_bmask.png and ISIC_0024946.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024946.png
# Processing: ISIC_0024947_bmask.png and ISIC_0024947.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024947.png
# Processing: ISIC_0024948_bmask.png and ISIC_0024948.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024948.png
# Processing: ISIC_0024949_bmask.png and ISIC_0024949.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024949.png
# Processing: ISIC_0024950_bmask.png and ISIC_0024950.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024950.png
# Processing: ISIC_0024951_bmask.png and ISIC_0024951.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024951.png
# Processing: ISIC_0024952_bmask.png and ISIC_0024952.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024952.png
# Processing: ISIC_0024953_bmask.png and ISIC_0024953.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024953.png
# Processing: ISIC_0024954_bmask.png and ISIC_0024954.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024954.png
# Processing: ISIC_0024955_bmask.png and ISIC_0024955.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024955.png
# Processing: ISIC_0024956_bmask.png and ISIC_0024956.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024956.png
# Processing: ISIC_0024957_bmask.png and ISIC_0024957.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024957.png
# Processing: ISIC_0024958_bmask.png and ISIC_0024958.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024958.png
# Processing: ISIC_0024959_bmask.png and ISIC_0024959.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024959.png
# Processing: ISIC_0024960_bmask.png and ISIC_0024960.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024960.png
# Processing: ISIC_0024961_bmask.png and ISIC_0024961.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024961.png
# Processing: ISIC_0024962_bmask.png and ISIC_0024962.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024962.png
# Processing: ISIC_0024963_bmask.png and ISIC_0024963.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024963.png
# Processing: ISIC_0024964_bmask.png and ISIC_0024964.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024964.png
# Processing: ISIC_0024965_bmask.png and ISIC_0024965.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024965.png
# Processing: ISIC_0024966_bmask.png and ISIC_0024966.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024966.png
# Processing: ISIC_0024967_bmask.png and ISIC_0024967.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024967.png
# Processing: ISIC_0024968_bmask.png and ISIC_0024968.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024968.png
# Processing: ISIC_0024969_bmask.png and ISIC_0024969.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024969.png
# Processing: ISIC_0024970_bmask.png and ISIC_0024970.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024970.png
# Processing: ISIC_0024971_bmask.png and ISIC_0024971.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024971.png
# Processing: ISIC_0024972_bmask.png and ISIC_0024972.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024972.png
# Processing: ISIC_0024973_bmask.png and ISIC_0024973.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024973.png
# Processing: ISIC_0024974_bmask.png and ISIC_0024974.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024974.png
# Processing: ISIC_0024975_bmask.png and ISIC_0024975.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024975.png
# Processing: ISIC_0024976_bmask.png and ISIC_0024976.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024976.png
# Processing: ISIC_0024977_bmask.png and ISIC_0024977.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024977.png
# Processing: ISIC_0024978_bmask.png and ISIC_0024978.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024978.png
# Processing: ISIC_0024979_bmask.png and ISIC_0024979.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024979.png
# Processing: ISIC_0024980_bmask.png and ISIC_0024980.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024980.png
# Processing: ISIC_0024981_bmask.png and ISIC_0024981.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024981.png
# Processing: ISIC_0024982_bmask.png and ISIC_0024982.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024982.png
# Processing: ISIC_0024983_bmask.png and ISIC_0024983.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024983.png
# Processing: ISIC_0024984_bmask.png and ISIC_0024984.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024984.png
# Processing: ISIC_0024985_bmask.png and ISIC_0024985.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024985.png
# Processing: ISIC_0024986_bmask.png and ISIC_0024986.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024986.png
# Processing: ISIC_0024987_bmask.png and ISIC_0024987.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024987.png
# Processing: ISIC_0024988_bmask.png and ISIC_0024988.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024988.png
# Processing: ISIC_0024989_bmask.png and ISIC_0024989.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024989.png
# Processing: ISIC_0024990_bmask.png and ISIC_0024990.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024990.png
# Processing: ISIC_0024991_bmask.png and ISIC_0024991.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024991.png
# Processing: ISIC_0024992_bmask.png and ISIC_0024992.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024992.png
# Processing: ISIC_0024993_bmask.png and ISIC_0024993.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024993.png
# Processing: ISIC_0024994_bmask.png and ISIC_0024994.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024994.png
# Processing: ISIC_0024995_bmask.png and ISIC_0024995.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024995.png
# Processing: ISIC_0024996_bmask.png and ISIC_0024996.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024996.png
# Processing: ISIC_0024997_bmask.png and ISIC_0024997.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024997.png
# Processing: ISIC_0024998_bmask.png and ISIC_0024998.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024998.png
# Processing: ISIC_0024999_bmask.png and ISIC_0024999.npy
# Original shapes - Prediction: (352, 352), Ground Truth: (512, 512)
# Saved comparison to comparison_results\comparison_0024999.png
#
# Processed 681 images
# Average IoU: 0.7626
# Summary report saved to comparison_results\summary_report.txt
